# %%
! wget https://query.data.world/s/ykom6fpxso63tqjmgqfglgjbbyekxm
! mv ykom6fpxso63tqjmgqfglgjbbyekxm market_price.csv
# Out:
# --2022-11-01 08:57:07--  https://query.data.world/s/ykom6fpxso63tqjmgqfglgjbbyekxm
# Resolving query.data.world (query.data.world)... 151.101.2.133, 151.101.66.133, 151.101.130.133, ...
# Connecting to query.data.world (query.data.world)|151.101.2.133|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://download.data.world/file_download/dcereijo/player-scores/player_valuations?auth=eyJhbGciOiJIUzUxMiJ9..pnEjFIXbrfJG10mTaErdO8Rs_JAO7pFQs6FyW7l6hc8fmTM_Ca5W7fTcGJDzJ9rt6G8YiHs9XO3HeFkkbLpQBQ [following]
# ...

# %%
import pandas as pd

# %%
market_price = pd.read_csv('/content/market_price.csv')
market_price.head()
# Out:
#    player_id        date  market_value    datetime    dateweek  \
# 0     254016  2013-07-22         90000  2013-07-22  2013-07-22
# 1     254016  2014-01-14         90000  2014-01-14  2014-01-13
# 2      51053  2008-08-25         90000  2008-08-25  2008-08-25
# 3      51053  2011-05-30         90000  2011-05-30  2011-05-30
# 4      51053  2011-08-26        225000  2011-08-26  2011-08-22
#
#    current_club_id player_club_domestic_competition_id
# 0              855                                 FR1
# 1              855                                 FR1
# 2               23                                  L1
# 3               23                                  L1
# 4               23                                  L1

# %%
# 최신일자 확인
df = market_price.sort_values(by=[market_price.columns[1]], ascending=False)
df.head()
# Out:
#         player_id        date  market_value    datetime    dateweek  \
# 329750     443124  2022-08-05        180000  2022-08-05  2022-08-01
# 337621     406766  2022-08-05        900000  2022-08-05  2022-08-01
# 279656      66515  2022-08-05       2250000  2022-08-05  2022-08-01
# 248522      41414  2022-08-05        900000  2022-08-05  2022-08-01
# 333166     662950  2022-08-05        180000  2022-08-05  2022-08-01
#
#         current_club_id player_club_domestic_competition_id
# 329750             7378                                 PO1
# 337621             3329                                 PO1
# 279656              114                                 TR1
# 248522              398                                 IT1
# 333166             3329                                 PO1

# %%
df[df['player_club_domestic_competition_id']=='PL']
# Out:
# Empty DataFrame
# Columns: [player_id, date, market_value, datetime, dateweek, current_club_id, player_club_domestic_competition_id]
# Index: []
